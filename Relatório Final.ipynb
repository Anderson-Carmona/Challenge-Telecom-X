# %%
Finalize o desafio elaborando um relatório dentro do próprio notebook que resuma todo o trabalho realizado. O relatório deve incluir:
Introdução: Explique o objetivo da análise e o problema de evasão de clientes (Churn).
Limpeza e Tratamento de Dados: Descreva os passos realizados para importar, limpar e tratar os dados.
Análise Exploratória de Dados: Apresente as análises feitas, incluindo gráficos e visualizações para identificar padrões.
Conclusões e Insights: Resuma os principais achados e como esses dados podem ajudar a reduzir a evasão.
Recomendações: Ofereça sugestões baseadas na sua análise.
•
O relatório de Análise Exploratória de Dados (AED) sobre a evasão de clientes (Churn) foi gerado e está formatado dentro do notebook com todas as seções solicitadas.
O relatório sintetiza os achados dos passos anteriores e apresenta novas conclusões ao comparar as médias das variáveis numéricas (Age, Annual_Income_k, Spending_Score) entre clientes Retidos e Evasivos.
________________________________________
Principais Destaques do Relatório:
•	Taxa de Churn: A taxa geral de evasão é de 25.5%.
•	Perfil de Risco (Categorias): Clientes Não Idosos (27.15%) e aqueles que usam Cartão de Crédito (Automático) (27.27%) têm as maiores taxas de evasão.
•	Perfil de Risco (Numéricas): Clientes evasivos são, em média, mais velhos e têm Pontuação de Gasto menor (48.87) do que os clientes retidos (52.51). A baixa pontuação de gasto é o insight numérico mais crítico.
•	Recomendação Central: O foco deve estar em clientes de baixo gasto com campanhas de engajamento personalizadas para aumentar a percepção de valor e, consequentemente, a retenção.
________________________________________
Este passo finaliza o desafio de análise exploratória. Se houver interesse em avançar para a próxima etapa de um projeto de data science, o caminho lógico seria a Modelagem Preditiva (por exemplo, classificação) ou Segmentação (Clustering).
# Out:
#   File "/tmp/ipython-input-2104601698.py", line 7
#     •
#     ^
# SyntaxError: invalid character '•' (U+2022)
