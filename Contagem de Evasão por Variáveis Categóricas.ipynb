# %%
Agora, vamos explorar como a evasão se distribui de acordo com variáveis categóricas, como gênero, tipo de contrato, método de pagamento, entre outras.
Essa análise pode revelar padrões interessantes, como, por exemplo, se clientes de determinados perfis têm maior tendência a cancelar o serviço, o que ajudará a direcionar ações estratégicas.
•
🕵️ Análise da Evasão por Variáveis Categóricas
A análise da taxa de evasão por variáveis categóricas ajuda a identificar quais segmentos de clientes estão mais propensos a cancelar o serviço. Abaixo estão os resultados, detalhando a contagem e a taxa de evasão para cada categoria:
________________________________________
🧍 Evasão por Gênero (Gender)
Gênero	Total de Clientes	Clientes Evasivos	Taxa de Evasão (%)
Feminino	100	28	28.00
Masculino	100	23	23.00
•	Padrão: Clientes do Gênero Feminino apresentaram uma taxa de evasão marginalmente maior (28.00%) em comparação com o Gênero Masculino (23.00%).
________________________________________
📜 Evasão por Tipo de Contrato (Contract_Type)
Tipo de Contrato	Total de Clientes	Clientes Evasivos	Taxa de Evasão (%)
Mensal (Month-to-month)	94	24	25.53
Anual (One year)	71	18	25.35
Bienal (Two year)	35	9	25.71
•	Padrão: Curiosamente, no conjunto de dados simulado, a taxa de evasão é muito similar entre todos os tipos de contrato (próxima a 25-26%). Em dados reais de telecomunicações, o contrato mensal geralmente apresenta uma taxa de evasão significativamente maior por oferecer menos barreiras de saída, mas isso não é observado aqui.
________________________________________
💳 Evasão por Método de Pagamento (Payment_Method)
Método de Pagamento	Total de Clientes	Clientes Evasivos	Taxa de Evasão (%)
Transferência Bancária (Automática)	49	13	26.53
Cartão de Crédito (Automático)	44	12	27.27
Cheque Eletrônico	51	11	21.57
Cheque Enviado por Correio	56	15	26.79
•	Padrão: Os clientes que pagam com Cartão de Crédito (Automático) têm a maior taxa de evasão (27.27%), seguidos de perto pelos que usam Transferência Bancária e Cheque por Correio. Curiosamente, o Cheque Eletrônico apresenta a menor taxa de evasão (21.57%).
________________________________________
👴 Evasão por Idoso (Senior_Citizen)
Idoso (1=Sim)	Total de Clientes	Clientes Evasivos	Taxa de Evasão (%)
0 (Não Idoso)	151	41	27.15
1 (Idoso)	49	10	20.41
•	Padrão: Os clientes Não Idosos (0) demonstram uma taxa de evasão consideravelmente mais alta (27.15%) em comparação com os clientes Idosos (1), que têm uma taxa de 20.41%.
________________________________________
🎯 Principais Achados para Estratégia
Os grupos com maior taxa de evasão neste conjunto de dados simulado são:
1.	Método de Pagamento: Clientes usando Cartão de Crédito (Automático).
2.	Idoso: Clientes Não Idosos (idade menor que 65 anos).
O próximo passo lógico é cruzar a variável Churn com as variáveis numéricas (Idade, Renda Anual e Pontuação de Gasto) para entender se a média de gasto ou renda difere significativamente entre clientes que permanecem e os que evadem.
Gostaria de realizar uma análise da média das variáveis numéricas (Age, Annual_Income_k, Spending_Score) por cada grupo de Churn para visualizar essas diferenças?
# Out:
#   File "/tmp/ipython-input-3646286103.py", line 3
#     •
#     ^
# SyntaxError: invalid character '•' (U+2022)
