# %%
Neste passo, verifique se há problemas nos dados que possam afetar a análise. Fique atento a valores ausentes, duplicados, erros de formatação e inconsistências nas categorias. Esse processo é essencial para garantir que os dados estejam prontos para as próximas etapas.
🔎 Verificação de Qualidade dos Dados
Essa é uma etapa crucial no processo de análise de dados. Sem ver dados específicos ou o seu dataset, eu não posso executar a verificação diretamente, mas posso fornecer as quatro áreas principais em que você deve se concentrar e as ações para tratar cada problema.
________________________________________
1. Valores Ausentes (Missing Values)
Valores ausentes (representados por NaN, Null, None ou um valor específico como ? ou -1) podem distorcer estatísticas e levar a modelos tendenciosos.
•	Ações Recomendadas:
•	Identificar: Conte a proporção de valores ausentes por coluna.
•	Tratar:
•	Remoção: Se a coluna tiver uma alta porcentagem de valores ausentes (ex: > 60-70%) ou se o número de linhas com valores ausentes for pequeno.
•	Imputação: Preencher os valores ausentes com a média (para dados numéricos sem outliers), mediana (para dados numéricos com outliers), ou a moda (para dados categóricos).
•	Modelagem: Usar modelos mais avançados para prever os valores ausentes (se for justificado).
________________________________________
2. Dados Duplicados (Duplicated Data)
Linhas completamente duplicadas ou chaves duplicadas (em um identificador único) podem inflar o dataset, introduzir viés e violar suposições de modelos.
•	Ações Recomendadas:
•	Identificar: Verifique se há linhas exatamente iguais.
•	Tratar: Remova as duplicatas, mantendo apenas a primeira ocorrência. Certifique-se de que a duplicidade não é intencional (ex: transações múltiplas).
________________________________________
3. Erros de Formatação e Tipos de Dados
Inconsistências no formato dos dados dentro da mesma coluna, ou tipos de dados incorretos, podem impedir cálculos e causar erros.
•	Ações Recomendadas:
•	Tipos de Dados:
•	Verifique se as colunas numéricas estão como int ou float e não como string (objeto).
•	Converta datas/horas de string para o formato datetime.
•	Formatação:
•	Remova caracteres especiais (ex: $ , %, vírgulas como separador de milhares) de colunas numéricas antes de converter o tipo.
•	Unifique o formato de datas (ex: de "DD-MM-AAAA" para "AAAA-MM-DD").
•	Trate espaços em branco extras (liderando ou rastejando) em colunas de texto.
________________________________________
4. Inconsistências Categóricas e Outliers
💡 Inconsistências Categóricas (Categorical Inconsistency)
O mesmo valor é representado de diferentes maneiras, afetando a contagem de categorias.
•	Ações Recomendadas:
•	Identificar: Use a contagem de valores únicos para colunas categóricas.
•	Tratar:
•	Padronizar o Case: Converta todas as strings para maiúsculas ou minúsculas (ex: "Brasil", "brasil" e "BRASIL" se tornam "brasil").
•	Corrigir Erros de Digitação: Corrija erros de grafia que representam a mesma categoria (ex: "Eletronicos" e "Eletrônicos").
⚠️ Outliers (Valores Atípicos)
Valores que se desviam significativamente dos outros. Embora nem sempre sejam erros, eles podem indicar um erro de entrada de dados ou podem distorcer medidas estatísticas.
•	Ações Recomendadas:
•	Identificar: Use gráficos de caixa (box plots), desvio padrão ou o escore Z (Z-score).
•	Tratar:
•	Investigar: Verifique se o outlier é um erro de digitação (ex: idade de 200 anos) e corrija-o, ou se é um evento raro válido.
•	Transformação: Use a mediana para imputação ou aplique transformações logarítmicas se o outlier for válido.
•	Limitação: Limite o valor no outlier para um percentil específico (técnica de winsorizing).
________________________________________
Próximo Passo: Compartilhe a saída das verificações de valores ausentes e duplicados, ou as primeiras linhas do dataset (se for possível), para que eu possa ajudá-lo a priorizar a limpeza.
https://pandas.pydata.org/docs/reference/api/pandas.unique.html
💡 Função pandas.unique
A função pandas.unique(values) é uma função de nível superior do pacote Pandas que retorna os valores únicos de um array-like (como uma Series ou um array NumPy) com base em uma tabela hash.
É uma ferramenta fundamental para a exploração e limpeza de dados, especialmente para inspecionar valores em colunas categóricas ou para identificar a extensão de valores distintos.
________________________________________
Principais Características
•	Finalidade: Identificar e extrair todos os valores distintos (únicos) de um objeto unidimensional.
•	Velocidade: É significativamente mais rápida que a função numpy.unique para sequências suficientemente longas, pois é otimizada para o uso com estruturas de dados do Pandas.
•	Ordem de Retorno: Os valores únicos são retornados na ordem de sua primeira ocorrência. A função não ordena o resultado.
•	Valores Ausentes (NA): Os valores ausentes (NaN ou None) são incluídos no array de retorno como um valor único.
________________________________________
Sintaxe e Retorno
A função opera diretamente sobre um array-like de uma dimensão.
Python
pandas.unique(values)
Parâmetro	Tipo	Descrição
values	1d array-like	O objeto (Series, Index, ou array NumPy) a ser verificado.
•	Valor de Retorno: Um numpy.ndarray ou uma ExtensionArray (para tipos de dados como Categorical, DatetimeIndex, etc.), contendo apenas os valores únicos na ordem de sua primeira aparição.
________________________________________
Comparação com Métodos Relacionados
Embora pandas.unique() seja uma função de nível superior, é mais comum na prática usar o método .unique() diretamente em um objeto Series ou Index.
Método	Aplicação	Resultado	Uso Típico
Series.unique()	Aplicado a uma coluna (Series).	numpy.ndarray (ou ExtensionArray) dos valores únicos.	Obter a lista de valores únicos em uma coluna.
Series.nunique()	Aplicado a uma coluna (Series).	Um int que é a contagem de valores únicos (por padrão, exclui NaN).	Obter a quantidade de valores únicos em uma coluna.
Series.value_counts()	Aplicado a uma coluna (Series).	Uma nova Series onde o Index são os valores únicos e os Valores são suas respectivas contagens.	Análise de frequência de valores em uma coluna categórica.
DataFrame.drop_duplicates()	Aplicado a um DataFrame.	Um novo DataFrame com linhas duplicadas removidas (pode usar um subconjunto de colunas para definir a duplicidade).	Remoção de registros duplicados do dataset.
Exemplo: Se você tem um DataFrame df com uma coluna 'Cidade':
•	df['Cidade'].unique(): Retorna uma array com os nomes das cidades distintas.
•	df['Cidade'].nunique(): Retorna o número total de cidades distintas.
https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.normalize.html
📆 Método Series.dt.normalize() do Pandas
O método Series.dt.normalize() é uma função essencial para a limpeza e padronização de dados temporais em Pandas. Ele faz parte do acessor .dt (Datetime), que só pode ser aplicado a uma Series com valores do tipo datetime64.
________________________________________
🎯 Funcionalidade Principal
O normalize() tem a função de converter o componente de tempo (hora, minuto, segundo, milissegundo, etc.) de cada registro de data e hora para meia-noite (00:00:00), mantendo a data e o fuso horário originais inalterados.
•	Objetivo: Reduzir todas as timestamps de um dia específico para o ponto inicial daquele dia.
🛠️ Aplicação na Análise de Dados
Esta função é particularmente útil quando:
1.	A Hora Não Importa: Em análises que focam apenas na data (eventos diários, registros de vendas por dia, etc.), a componente de tempo é ruído. Normalizar garante que todas as ocorrências de um mesmo dia sejam agrupadas corretamente.
2.	Agrupamento Simplificado: Permite que você agrupe facilmente dados por data, pois 2025-11-25 10:30:00 e 2025-11-25 18:45:00 serão ambos convertidos para 2025-11-25 00:00:00, facilitando a contagem ou agregação por dia.
3.	Comparação Precisa: Padroniza as timestamps para que comparações simples de igualdade (==) entre datas retornem resultados esperados, mesmo que as horas originais fossem diferentes.
📝 Sintaxe
O método não requer parâmetros:
Python
Series.dt.normalize()
Parâmetro	Descrição
Retorno	Uma nova Series ou DatetimeIndex do mesmo tipo, com a hora de todos os valores definida como 00:00:00.
Exemplo Ilustrativo
Se você tem a seguinte Series de datas e horas:
Índice	Valor Original
0	2025-11-25 10:30:00
1	2025-11-25 23:59:59
2	2025-11-26 01:15:00
Ao aplicar dt.normalize(), o resultado será:
Índice	Valor Normalizado
0	2025-11-25 00:00:00
1	2025-11-25 00:00:00
2	2025-11-26 00:00:00
Observe que, após a normalização, os dois primeiros valores são idênticos, o que permite o agrupamento correto por data.
# Out:
#   File "/tmp/ipython-input-3877012406.py", line 2
#     🔎 Verificação de Qualidade dos Dados
#     ^
# SyntaxError: invalid character '🔎' (U+1F50E)
