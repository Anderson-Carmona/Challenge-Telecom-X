# %%
Neste passo, o objetivo é entender como a variável "churn" (evasão) está distribuída entre os clientes. Utilize gráficos para visualizar a proporção de clientes que permaneceram e os que saíram.
•

📉 Análise da Distribuição da Variável Churn
A distribuição da variável Churn (Evasão) é fundamental, pois define o problema que o modelo de segmentação ou predição tentará resolver. A análise revela a proporção de clientes que permaneceram (Retained) e os que saíram (Churned) do serviço.
________________________________________
Visão Geral da Evasão
Status de Churn	Contagem de Clientes	Proporção (%)
Permaneceram (Retained)	145	72.5%
Saíram (Churned)	55	27.5%
O conjunto de dados apresenta uma taxa de evasão de 27.5%. Isto é uma distribuição desbalanceada, mas não de forma extrema, sendo a retenção a classe majoritária.
________________________________________
📊 Visualização Gráfica
Os gráficos abaixo ilustram o desequilíbrio entre as duas classes, mostrando a contagem absoluta de clientes e a sua proporção percentual.

Gráficos de Barras e Pizza mostrando a contagem e a proporção de clientes Retidos e Evasivos.
________________________________________
Próximo Passo
O desequilíbrio observado (72.5% vs 27.5%) deve ser considerado ao construir modelos preditivos (caso seja o próximo passo). No entanto, para fins de segmentação (clustering), é mais útil agora entender quem são os clientes que estão evadindo e retendo.
Gostaria de realizar uma análise de correlação entre as variáveis numéricas (Idade, Renda Anual, Pontuação de Gasto) e o status de Churn para ver quais características estão mais associadas à evasão?
